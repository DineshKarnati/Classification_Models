# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\dines\Downloads\nyc_weather.csv")

# %%
df.head(3)
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df['EST'][df['Events'] == "Rain"]  # Get all dates when it rains
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df['WindDirDegrees'].mean()  # get avg values of a column
# Out:
# 247.1290322580645

# %%
df.fillna(0, inplace= True)

# %%
df[['EST', 'Events']]
# Out:
#           EST    Events
# 0    1/1/2016         0
# 1    1/2/2016         0
# 2    1/3/2016         0
# 3    1/4/2016         0
# 4    1/5/2016         0
# 5    1/6/2016         0
# 6    1/7/2016         0
# 7    1/8/2016         0
# 8    1/9/2016      Rain
# 9   1/10/2016      Rain
# 10  1/11/2016         0
# 11  1/12/2016         0
# 12  1/13/2016         0
# 13  1/14/2016         0
# 14  1/15/2016         0
# 15  1/16/2016      Rain
# 16  1/17/2016  Fog-Snow
# 17  1/18/2016      Snow
# 18  1/19/2016         0
# 19  1/20/2016         0
# 20  1/21/2016         0
# 21  1/22/2016      Snow
# 22  1/23/2016  Fog-Snow
# 23  1/24/2016      Snow
# 24  1/25/2016         0
# 25  1/26/2016         0
# 26  1/27/2016      Rain
# 27  1/28/2016         0
# 28  1/29/2016         0
# 29  1/30/2016         0
# 30  1/31/2016         0

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     31.000000   31.000000       31.000000
# mean          9.193548      6.225806    3.129032      247.129032
# std           1.939405      3.422569    2.629853       92.308086
# min           1.000000      0.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
df[df['Temperature']>32]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# ...

# %%
df[['EST', 'Events']][df['Temperature']>32]
# Out:
#           EST    Events
# 0    1/1/2016         0
# 1    1/2/2016         0
# 2    1/3/2016         0
# 5    1/6/2016         0
# 6    1/7/2016         0
# 7    1/8/2016         0
# 8    1/9/2016      Rain
# 9   1/10/2016      Rain
# 10  1/11/2016         0
# 11  1/12/2016         0
# 14  1/15/2016         0
# 15  1/16/2016      Rain
# 16  1/17/2016  Fog-Snow
# 24  1/25/2016         0
# 25  1/26/2016         0
# 26  1/27/2016      Rain
# 27  1/28/2016         0
# 28  1/29/2016         0
# 29  1/30/2016         0
# 30  1/31/2016         0

# %%
import pandas as pd
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'windspeed': [6,7,2],
    'event': ['Rain', 'Sunny', 'Snow']
}
new_df = pd.DataFrame(weather_data)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
weather_data = [
    ('1/1/2017',32,6,'Rain'),
    ('1/2/2017',35,7,'Sunny'),
    ('1/3/2017',28,2,'Snow')
]
ndf = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
ndf
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
new_dfff = pd.concat([ndf, new_df])

# %%
new_dfff
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
weather_data = [
    {'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
    {'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
    {'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'},
    
]
g = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
g
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
eventsgroupby = df[df['Events'] != 0].groupby('Events')

# %%
for i, j in eventsgroupby:
    print(i) # distinct column vakues
    print(j) # dataframe
# Out:
# Fog-Snow
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 16  1/17/2016           36        23        66                 29.78
# 22  1/23/2016           26        21        78                 29.77
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 16                8           6.0            0.05           6  Fog-Snow
# 22                1          16.0            2.31           8  Fog-Snow
#
#     WindDirDegrees
# 16             345
# 22              42
# Rain
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 15  1/16/2016           47        37        70                 29.52
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# ...

# %%
eventsgroupby.get_group('Snow')
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 17  1/18/2016           25         6        53                 29.83
# 21  1/22/2016           26         6        41                 30.21
# 23  1/24/2016           28        11        53                 29.92
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 17                9          12.0               T           2   Snow
# 21                9           0.0            0.01           3   Snow
# 23                8           6.0               T           3   Snow
#
#     WindDirDegrees
# 17             293
# 21              34
# 23             327

# %%
eventsgroupby.max()
# Out:
#                 EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# Events
# Fog-Snow  1/23/2016           36        23        78                 29.78
# Rain       1/9/2016           50        46        77                 30.16
# Snow      1/24/2016           28        11        53                 30.21
#
#           VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover  \
# Events
# Fog-Snow                8          16.0            2.31           8
# Rain                   10           8.0               T           8
# Snow                    9          12.0               T           3
#
#           WindDirDegrees
# Events
# Fog-Snow             345
# Rain                 340
# Snow                 327

# %%
eventsgroupby.plot()
# Out:
# Events
# Fog-Snow    Axes(0.125,0.11;0.775x0.77)
# Rain        Axes(0.125,0.11;0.775x0.77)
# Snow        Axes(0.125,0.11;0.775x0.77)
# dtype: object
